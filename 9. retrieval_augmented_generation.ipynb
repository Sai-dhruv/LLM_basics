# %% [markdown]
# #### 🏗️ 9. Retrieval-Augmented Generation (RAG)

# %% [markdown]
# #### 🔹 What is RAG?
#
#     RAG combines search + LLMs.
#
#     Instead of relying only on what the LLM was trained on, RAG:
#
#     Retrieves relevant external knowledge
#
#     Injects it into the prompt
#
#     Generates grounded, up-to-date answers
#
# 👉 This drastically reduces hallucinations.

# %% [markdown]
# #### 🔁 The Most Common RAG Pipeline
# Load → Split → Embed → Store → Retrieve → LLM

# %% [markdown]
# #### 🧠 Why RAG is Important
#
#     LLMs don’t know your private data
#
#     LLMs can hallucinate
#
#     Training/fine-tuning is expensive
#
# 👉 RAG gives:
#
#     Fresh data
#
#     Enterprise grounding
#
#     Lower cost
#
#     Explainability

# %% [markdown]
# #### 🚀 Advanced RAG Techniques (High-Impact Interview Topics)

# %% [markdown]
# #### 1️⃣ RAG-Fusion (Multiple Query Expansion)
#
# 🔹 Problem
#
#     A single user query may miss relevant documents.
#
# 🔹 Solution
#
#         LLM generates multiple rewritten queries
#
#         Retrieve results for each
#
#         Merge and rank them
#
#     Example:
#
#         “How does reimbursement work?”
#
#     Expanded to:
#
#         “Expense reimbursement policy”
#
#         “Employee reimbursement rules”
#
#         “Claim submission workflow”

# %% [markdown]
# #### 2️⃣ LLM-Based Ranking (Re-ranking)
# 🔹 What it does
#
#         Retrieve top-N chunks
#
#         Ask an LLM to re-rank by relevance
#
# 🔹 Why it matters
#
#         Vector similarity ≠ perfect relevance
#
#     LLM understands:
#
#     Question intent
#
#         Contextual relevance
#
# Trade-off:
# ❌ Extra LLM cost
# ✅ Much better answer quality

# %% [markdown]
# #### 3️⃣ Graph RAG (Knowledge Graph + Embeddings)
# 🔹 What it is
#
#         Documents are converted into entities + relationships
#
#         Stored as a knowledge graph
#
#         Combined with embeddings
#
#     Example:
#
#         Employee → works_in → Department
#         Policy → applies_to → Employee
#
# 🔹 Why it’s powerful
#
#         Multi-hop reasoning
#
#         Relationship-aware answers
#
#         Excellent for compliance, finance, healthcare
#
# ✅ Used in enterprise & regulated domains

# %% [markdown]
# #### 4️⃣ HyDE (Hypothetical Document Embeddings)
# 🔹 Key idea
#
#         Instead of embedding the question, the LLM:
#
#         Generates a hypothetical answer
#
#         Embeds that answer
#
#         Searches using it
#
# Why this works:
#
#         Hypothetical answer is closer to real documents
#
#         Better semantic alignment
#
# Example:
#     Question:
#
#         “What is leave carryover policy?”
#
#         LLM creates:
#
#             “Employees can carry forward unused leave up to…”
#
#             Then searches using that text.
#
# ✅ Improves retrieval quality for vague questions

# %% [markdown]
# #### 5️⃣ Self-RAG / ReAct-RAG
#
# 🔹 What it does
#
#         LLM reasons about its own answers:
#
#         Do I need more info?
#
#         Should I retrieve again?
#
#         Is my answer confident?
#
# Loop:
#
#     Think → Retrieve → Answer → Reflect → Retrieve again
#
# 🔹 Why it matters
#
#         Agent-like behavior
#
#         Higher accuracy
#
#         Dynamic decision making
#
# ✅ Used in agentic AI systems
