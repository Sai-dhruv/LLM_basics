# %% [markdown]
# ### 4. Retrieval-Augmented Generation (RAG)
#     4.1 Document Loading
#             * File loaders
#                 PDF (PyPDFLoader/Docling/Nougat)
#                 Text
#                 Word
#                 HTML
#                 Markdown
#             * Web loaders
#                 WebBaseLoader
#                 PlaywrightLoader (dynamic sites)
#                 SitemapLoader
#             * Cloud loaders
#                 S3 loader
#                 GCS loader
#                 Azure Blob loader
#     4.2 Text Splitting
#                 RecursiveCharacterTextSplitter — BEST for most cases
#                 Token-based (OpenAI’s tiktoken)
#                 Document-specific (Markdown, HTML, Python code)
#     4.3 Embeddings
#             * Embeddings convert text → numeric vectors.
#             * Popular Embedding Models
#             * OpenAIEmbeddings
#             * CohereEmbeddings
#             * HuggingFaceEmbeddings
#             * Google VertexAI embeddings
#             * Jina embeddings
#     4.4 Key Concepts
#             * Dimensionality
#             * Context window
#             * Similarity metrics (cosine, dot)
#             * Performance trade-offs
#
#     4.5 Vector Stores (Databases for RAG)
#             FAISS (local)
#             ChromaDB (local)
#             Pinecone (managed)
#             Weaviate
#             Milvus
#             Elasticsearch
#
#             Important topics
#                 Index creation
#                 Metadata filters
#                 Hybrid search (dense + keyword)
#                 Incremental updates
#     4.6. Retrievers
#             VectorStoreRetriever
#             MultiQueryRetriever (uses LLM to rewrite queries)
#             ContextualCompressionRetriever
#             ParentDocumentRetriever
#             EnsembleRetriever (combines BM25 + vector search)
#
#     4.7 Retrieval-Augmented Generation (RAG)
#             The most common RAG pipeline:
#             Load → Split → Embed → Store → Retrieve → LLM
#             Advanced RAG techniques
#                 RAG-Fusion (multiple query expansion)
#                 LLM-based ranking
#                 Graph RAG (knowledge graph embeddings)
#                 HyDE (Hypothetical Document Embeddings)
#                 Self-RAG / ReAct-RAG

# %% [markdown]
# ✅ 4.1 Document Loading
#
#      * File loaders

# %% [markdown]
# ##### PDF — PyPDFLoader

# %%
#!pip install pypdf

# %%
a) PyPDFLoader

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("saikrishna_java_fullstack_developer.pdf")
docs = loader.load()

# %%
b) PDF — Docling
c) PDF — Nougat OCR
d) Text Files
e) Word Documents (.docx)
f) HTML
g) Markdown
h) Web Loader — static pages
i) Playwright Loader — dynamic JS website
j) Sitemap Loader
k) S3 Loader

# %% [markdown]
# #### ✅ 4.2 Text Splitting

# %% [markdown]
# a) RecursiveCharacterTextSplitter (BEST)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
chunks = splitter.split_documents(docs)
chunks
# Out:
# [Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='Saikrishna Vinjamuri\nsaikrishna.spark@gmail.com\n4694492774\nProfessional Summary:\nJava Full Stack Engineer with 10+ years of experience in designing and developing enterprise\napplications using Java, Spring Boot and AWS. Proficient in building scalable microservices and\nintegrating LLM-based AI solutions using LangChain, Amazon Bedrock, and Cohere. Strong expertise\nin RESTful APIs and intelligent document processing.\nSummary:'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='Summary:\n● Proficient in software analysis, design, development, and implementation usingJava.\n● Built and deployed Spring Boot –based backend services for high-throughput applications\nintegrated with AWS components likeS3, RDS, andDynamoDB.\n● Developed frontend user interfaces using React.js, implementing reusable components, state\nmanagement and form validations.\n● Followed microservices best practices such as centralized logging (Log4j/CloudWatch),'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='externalized configuration, and service decoupling.\n● Expertise in cloud services includingGlue, RDS, S3, Lambda, SNS, API Gateway, R53, DynamoDB,\nand CloudWatch.\n● Strong understanding of cloud security measures, including IAM, Security Groups, and VPC\nconfigurations.\n● Designed the approach and implemented the multiple applications into Amazon Web Services -\nAWS (including Lambda, EC2, RDS, SNS, S3 Storage,and others).'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='● Utilized LLMs to facilitate natural language understanding and generation, enabling users to\ninteract with documents conversationally.\n● Integrated Pinecone vector database to store and retrieve document embeddings, enhancing\nthe speed and efficiency of similarity searches.\n● Implemented document chunking techniques to break lengthy documents into smaller,\ncontextually coherent segments.\n● Applied LangChain prompt engineering to craft precise and effective prompts, guiding LLMs to'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='provide contextually appropriate answers based on document content.\n● Developed RAG systems that combine LLMs with document retrieval techniques to generate\nresponses grounded in external data.\n● Collaborated with cross-functional teams includingUI/UX designers, product managers, and\nQA engineers to deliver seamless and high-performing applications.\n● Wrote clean, modular, and testable code with adherence toSOLID principles and conducted\nthorough unit and integration testing.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='thorough unit and integration testing.\n● Implemented security best practices for authentication, authorization, data protection, and API\nmanagement using OAuth2, HTTPS, and secure token storage.\n● Developed Kafka producers and consumersusing Python and Java to efficiently process and\ndistribute streaming data.\n● Containerized applications usingDocker, and managed deployments usingKubernetes for\norchestration in dev/test environments.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='Technical Skills:\nProgramming Languages : Java,Python, SQL\nAI / LLM Models : OpenAI, Hugging Face, Cohere\nFrameworks : Python Flask, Spring Boot, Microservices\nLangChain Framework : LangChain\nORM : Hibernate\nQuality Assurance & Code Analysis : SonarQube, Fortify, Pylint\nAWS Services : SNS, S3, Lambda, Security Management, RDS\nDatabases : MySQL, PostgreSQL, Amazon RDS, DynamoDB\nWeb Services : RESTful\nAuthentication & Security : OAuth2, Spring Security, AWS Secrets Manager, JWT'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='Front-End Technologies : React, JavaScript, HTML, CSS\nTools & IDEs : VS Code, Eclipse, Jupyter Notebook\nTest Frameworks : JUnit, Mockito\nVector Databases : Pinecone, ChromaDB\nCI/CD & DevOps : GitHub Actions, AWS Code Pipeline, Docker, Kubernetes\nEXPERIENCE:\nClient: CapitalOne OCT 2022 – till today\nDesignation: Sr. Software Engineer\nProject Name: Chat Models and Document-Based Question Answering\nExperienced in developing advanced chatbot systems utilizing Large Language Models (LLMs) ,'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content="specifically theCohere model, integrated withLangChain and thePinecone vector databasefor document-\nbased question-answering capabilities. Appliedprompt engineeringtechniques to optimize LLM responses,\nensuring accurate and contextually relevant answers based on document content. Implemented efficient\ndocument chunking to manage large texts, enhancing the model's retrieval accuracy. Expertise in\nembedding document data for seamless querying, enabling real-time interactions where users can ask"),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='questions and receive precise answers from various document formats.\nResponsibilities:\n● Designed and developed a document-based question answering system using Java for the\napplication layer and Python for backend LLM integration.\n● Designed and developed RESTful APIs in Java Spring Boot to serve as the orchestration layer for\ndocument processing and user interactions.\n● Utilized Cohere LLMs with LangChain to build a context-aware QA system capable of interpreting'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='user queries and returning document-specific answers.\n● Integrated Pinecone as the vector database to perform high-performance similarity search over\nembedded document chunks.\n● Integrated Cohere language models to interpret and answer natural language questions based on\nstructured and unstructured document content.\n● Implemented document chunking techniques to handle large documents, improving model\nefficiency by breaking down content into smaller, manageable pieces for better retrieval.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='● Created pipelines for embedding document data and making it searchable, supporting real-time,\naccurate question answering based on document content.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='● Optimized LLM-based chat interactions for faster response times and enhanced relevancy in\nresponses, providing users with meaningful answers extracted from diverse document formats.\n● Langchain-based architecture for chaining tasks like data retrieval, filtering, and ranking.\n● Used Python for NLP tasks, model orchestration, and integration with Cohere and Pinecone APIs.\n● Experience in implementing real-time data retrieval techniques to support dynamic querying.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='● Proficient in Python for implementing NLP tasks and integrating various components of the solution.\n● Built CI/CD pipelines using GitHub Actions and AWS CodePipeline for automated deployment of\nJava and Python components.\n● Designed API contracts and documentation using Swagger/OpenAPI, enabling seamless team\ncollaboration.\n● Implemented secure API authenticationusing OAuth2 and AWS Secrets Manager for managing API\nkeys and credentials.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content="keys and credentials.\n● Ensured robust error handling and loggingbetween services using CloudWatch.\n● Enhanced the system's scalability and adaptability by implementingprompt engineeringtechniques\nto manage user queries and responses dynamically.\nEnvironment: Java, Spring Boot, Python, Flask/FastAPI, LangChain, Cohere, Pinecone, REST APIs,\nDocker, AWS (Lambda, S3, CloudWatch), GitHub Actions, Swagger, Prompt Engineering, Microservices\nArchitecture\nProject Name: Feature Authoring SDK"),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='Architecture\nProject Name: Feature Authoring SDK\nFeature Platform SDK is the feature engineering development kit offered to data Scientist, Analyst\nand Engineers to author features and operationalize them on Enterprise Platform with being fully self-\nserviced.\nResponsibilities:\n● Implemented Feature View API in Java (Spring Boot) to expose feature authoring capabilities and\nsupport seamless integration with the enterprise platform.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='● Developed Metadata APImicroservice to persist feature metadata usingAWS DynamoDB, ensuring\nlow-latency, scalable metadata storage.\n● Enabled full self-service feature engineering with clean separation of concerns between feature\ndefinition and metadata handling.\n● Leveraged Spring Boot, RESTful APIs, and microservice architecture for scalability and\nmaintainability across services.\n● Ensured reliable inter-service communication, error handling, and deployment readiness for\nenterprise use.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='enterprise use.\n● Deployed both APIs asAWS Lambda functionsintegrated withAmazon API Gatewayto ensure high\navailability and cost efficiency.\n● Integrated AWS CloudWatch for centralized logging, monitoring, and debugging of API activity.\n● Adopted best practices inRESTful API design, serverless architecture, andmicroservice scalability.\n● Conduct code reviews and ensure the code follows best practices for distributed computing and\ndata engineering'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='data engineering\nEnvironment: Java, Maven, J2EE, Spring Boot, Microservices, React, Spring, GitHub, Log4J, Tomcat,\nJSON, GraphQL, Apache Kafka, Mockito, Sonar, Fortify Scan, DynamoDB, API Gate way, Docker,\nKubernetes, JWT, AWS DynamoDB, SNS, Cloud watch, AWS SQS and AWS'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='Cognizant Sep 2021 – Oct 2022\nClient: US Bank\nDesignation: Sr. Associate Projects\nProject Name: Generic SSO\nGoal is to find single sign on capabilities that can be used to across the enterprise we will share the\nhighly secured generic SSO options so that all teams can use. As part of this, Auth team building\na) Generic SSO API\nb) Generic SSO Component\nGeneric SSO API: Will take care of creating MID account in Cassandra table using service API, External id'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='shared to vendor system securely through authorization code flow using external API.\nGeneric SSO Component: This is a UI component which is integrated with login component, after\nsuccessfully login the login component will pass the transmit JWT token to generic SSO component\nwhich will initiate the API.\nResponsibilities:\n\ue12c Developed the functionalities using Agile Scrum Methodology.\n\ue12c Participated in requirements gathering and preparing business requirements documents.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='\ue12c Implemented the application using Spring Boot.\n\ue12c Implemented Micro-services.\n\ue12c Consumed Restful APIs provided by different vendor to user for user validation\n\ue12c Created new Restful APIs for different operations.\n\ue12c Implemented Junit test cases for Restful APIs .\n\ue12c Implemented UI screens Using Angular 8.\n\ue12c Used Spring Kafka API calls to process the messages smoothly on Kafka cluster setup.\n\ue12c Implemented Log4J for Logging, debugging and tracking using logging components'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='\ue12c Implemented server-side validations, exception handling.\n\ue12c Maintained proper coding standards and best practices.\n\ue12c Involved in preparing technical reports & documentation manuals during the program\ndevelopment.\n\ue12c AWS Lambda using java to perform event driven processing.\n\ue12c Used JIRA tool for Issue/bug tracking, monitoring of work assignment in the system.\n\ue12c Experience on implementation of version control software GIT repository.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='\ue12c Deployed applications into Continuous integration and Deployment (CI/CD) environments like\nJenkins.\n\ue12c Fixed sonar Issues and maintained 80 % code coverage all the time.\n\ue12c Fixed vulnerability Issues which are reported in fortify scan.\n\ue12c Implemented Multi Factor Authentication (MFA) solution implementation for Web applications.\n\ue12c Knowledge on Kubernetes to deploy containerized application.\n\ue12c Designed and implemented highly scalable reactive microservices using Java and Spring Boot on'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='WebFlux to enhance system responsiveness and reliability\nEnvironment: Jetty, Maven, J2EE, Spring Boot, Microservices, Angular, Spring, GitHub, Log4J,\nTomcat, JSON, GraphQL, Apache Kafka, Mockito, Sonar, Fortify Scan, Cassandra, API Gate way,\nDocker, Kubernetes, OAUTH2, Apache spark, SSO, MFA, AWS SQS and AWS.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='Infosys AUG 2017–2021\nClient: Westpac\nDesignation: Technology Analyst\nProject Name: Case Mgmt. and Complaint Mgmt. System\nTo mitigate and resolve some of the business and technology challenges, the complaint\nmanagement API is built. It is a case management system that allows us to capture a complaint in the\ndigital channel that it occurs, or in the digital channel that the customer prefers. It is developed. It is'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='developed on Westpac Digital Platform (WDP) and provides operations for working with complaints in\nthe Enterprise Content Management (ECM) system. The following operations are supported: Create\ncomplaints, Update complaints, Get complaints, Delete complaints, Search complaints, Create staff notes,\nUpdate staff notes, Delete staff notes, Create complaint interaction note, Update complaint interaction\nnote, Delete complaint interaction note, Get complaint notes.\nResponsibilities:'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='Responsibilities:\n● Developed the functionalities using Agile Scrum Methodology.\n● Participated in requirements gathering and preparing business requirements documents.\n● Developing API for operations like create, get, search case etc. using Rest webservice.\n● Performed Unit Testing of various modules by generating the Test Cases.\n● Code coverage, building and deploying service using Bamboo\n● Implemented Log4J for Logging, debugging and tracking using loggers components.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='● Implemented server-side validations, exception handling\n● Experienced with multi-threading programming.\n● Maintained proper coding standards and best practices.\n● AWS Lambda using java to perform event driven processing.\n● Involved in preparing technical reports & documentation manuals during the program\ndevelopment.\n● Used Bitbucket for version control and assembly for bug tracking.\n● Architecture Design and Development on IBM Platform\n● Design swagger for all the operations.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='● Design swagger for all the operations.\n● AWS Cloud with integration to S3 bucket.\n● Performed code review, integration and testing.\nEnvironment: Jetty, React, Maven, J2EE, Spring Boot, Microservices, Rest API, Swagger, SVN, Log4J,\nTomcat, Linux, JSON, FileNet API, AWS Lambda, OAUTH2, AWS S3 and AWS.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='VSoft Technologies Pvt Ltd APR 2015 – AUG 2017\nClient: Odisha State Cooperative Bank\nDesignation: Developer Engineer\nProject Name: Suvikas\nSuvikas is core banking product which is used by many cooperative banks in India\nbecause of its cost-effective and simplified flow developed as per the guidelines of RBI.\nThis issuer friendly, flexible and self-supporting application, that permits easy\nperformance, improves overall efficiency. This is platform independent and available'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='for both Windows and Linux. Modules like Admin, Cashier, Loans, Deposits, RBI\nReports ATM, Mobile Banking, Utility Bill Collection and it supports all type of account\nopening by defining their own product.\nResponsibilities:\n● Involved in the implementation of business logic in struts Framework and Hibernate in the back\nend.\n● Extensively worked on front end, business, and persistence tiers using the struts frameworks.\n● Designed and developed Service layer using struts framework.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='● Developed presentation layer using struts tag libraries like logic, html, bean, etc in JSP pages.\n● Developed use case diagrams, Class diagrams, database tables, and provided mapping between\nrelational database tables and object-oriented java objects using Hibernate.\n● Consumed Restful services to consume customer details.\n● Bug fixing for the existing product.\n● Used Postgres database & Hibernate to access the data.\n● Addressing issues at production and providing hot fixes.'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='● Customizing the product as per client requirement.\n● Implemented Log4J for Logging, debugging, and tracking using logging components.\n● Coded the front-end components like JSP, Action and Action Forms and Utility classes.\n● Wrote JUnit components for testing Service layer.\nEnvironment: Java 6, Maven, Tomcat, Spring MVC, Struts 2, Hibernate, Spring ORM, Spring Security,\nRest API, PostgreSQL, JSP, HTML, SVN, Log4J, Linux, JSON and Java script.\nEducation Details:'),
#  Document(metadata={'producer': 'www.smallpdf.com', 'creator': 'www.smallpdf.com', 'creationdate': 'D:20251209144849', 'moddate': 'D:20251209144849', 'source': 'saikrishna_java_fullstack_developer.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='Education Details:\n● Master of Computer Applications,2013 JNTU, Hyderabad, INDIA\n● Bachelors Of Science - Computer Science, 2010, Kakatiya University, INDIA')]

# %% [markdown]
# ### b) Token-based (OpenAI tiktoken)

# %%
from langchain_text_splitters import TokenTextSplitter

splitter = TokenTextSplitter(chunk_size=200, chunk_overlap=50)
chunks = splitter.split_documents(docs)

# %% [markdown]
# ### c) Markdown-specific splitting

# %%
from langchain_text_splitters import MarkdownHeaderTextSplitter

splitter = MarkdownHeaderTextSplitter(["#", "##", "###"])
chunks = splitter.split_text(open("notes.md").read())
chunks
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 from langchain_text_splitters import MarkdownHeaderTextSplitter
#       3 splitter = MarkdownHeaderTextSplitter(["#", "##", "###"])
# ----> 4 chunks = splitter.split_text(open("notes.md").read())
#       5 chunks
#
# File P:\GEN-AI\langchain-application\.venv\lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'notes.md'
