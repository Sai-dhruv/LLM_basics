# %% [markdown]
# #### 🤖 12. Agents

# %% [markdown]
# #### 🔹 What is an Agent?
#
#         An agent is an LLM that can:
#
#             Reason about a goal
#
#             Decide what action to take
#
# Use tools
#
#         Observe results
#
#         Iterate until the task is complete
#
# 👉 Unlike a normal LLM call, an agent controls the flow.

# %% [markdown]
# #### 🧠 Why Agents Matter
#
#         Agents enable:
#
#             Autonomous workflows
#
#             Multi-step problem solving
#
#             Tool orchestration
#
#             Reduced human intervention
#
# Examples:
#
#         Validate ML models automatically
#
#         Query data → analyze → summarize
#
#         Run incident investigation workflows

# %% [markdown]
# #### 🔁 Agent Loop (Very Important)
#
#     1. LLM thinks (reasoning)
#     2. Picks a tool
#     3. Tool executes
#     4. LLM observes result
#     5. Decides next step
#     (repeats until done)

# %% [markdown]
# #### 🧩 Types of Agents (Interview Focus)
#
# 🔹 What it is
#
#     Interleaves reasoning and tool usage
#
#     Think → Act → Observe → Think again
#
#     Example:
#             Thought: I need recent policy info
#             Action:  Search tool
#             Observation: Found HR policy doc
#             Thought: Extract leave rules

# %% [markdown]
# #### 2️⃣ OpenAI Function Agent
# 🔹 What it is
#
#         Uses structured function calling
#
# LLM outputs JSON to invoke tools
#
#     🔹 Why it’s production-friendly
#
#         Safer than free-text actions
#
#         Schema validation
#
#         Predictable execution
#
# 🔹 When to use
#
#         Enterprise systems
#
#         APIs, DBs, workflows

# %% [markdown]
# #### 3️⃣ Tool-Driven Agent (Multi-Tool)
#
# 🔹 What it is
#
#         Agent with access to many tools
#
#         Chooses tools dynamically
#
# 🔹 Example Tools
#
#         Search
#
#         Database
#
#         Calculator
#
#         Code execution
#
# 🔹 When to use
#
#         Complex business workflows
#
#         Data analysis
#
#         Automation pipelines

# %% [markdown]
# #### 4️⃣ Self-Ask Agent
# 🔹 What it is
#
#     Agent asks itself follow-up questions
#
#     Breaks complex problems into steps
#
# 🔹 Example
#
#         “What is revenue growth?”
#
#         Agent asks itself:
#
#         “What was last month revenue?”
#
#         “What was previous month revenue?”
#
# 🔹 When to use
#
#         Analytical reasoning
#
#         Multi-step logic without heavy tools

# %% [markdown]
# 5️⃣ Plan-and-Execute Agent
# 🔹 What it is
#
#     Two-phase approach:
#
#     Planning phase → create a task plan
#
#     Execution phase → run steps one by one
#
# 🔹 Example
#
# Plan:
#
# Load data
#
# Validate schema
#
# Compute metrics
#
# Generate report
#
# 🔹 Why it’s powerful
#
# More stable than ReAct
#
# Predictable workflows
#
# 🔹 When to use
#
# Long-running tasks
#
# Enterprise pipelines
#
# ML lifecycle automation
