# %% [markdown]
# #### 6. Embeddings — Explained Clearly
#
#     OpenAIEmbeddings
#     CohereEmbeddings
#     HuggingFaceEmbeddings
#     Google VertexAI embeddings
#     Jina embeddings

# %% [markdown]
# Embeddings convert text into numeric vectors (arrays of numbers) that capture the semantic meaning of the text.
#
# 👉 Similar meanings → vectors close together
# 👉 Different meanings → vectors far apart
#
# Example:
#
# “How to reset my password”
#
# “Forgot account password”
#
# ➡️ These will have very similar embeddings, even though the text is different.

# %% [markdown]
# #### 🧠 Why Embeddings Matter

# %% [markdown]
# #### 🔹Embeddings power:
#
#     Semantic Search
#
#     RAG (Retrieval-Augmented Generation)
#
#     Document similarity
#
#     Clustering & classification
#
#     Recommendation systems
#
#     LLMs understand text →
#     Vector databases understand embeddings

# %% [markdown]
# #### 1️⃣ Dimensionality
#
# Number of values in the vector
#     Examples:
#
#         384 → lightweight, faster
#
#         768 → balanced
#
#         1536+ → richer semantic meaning
#
#     Trade-off:
#
#         Higher dimensions = better meaning
#
#         Lower dimensions = faster search & less cost

# %% [markdown]
# #### 2️⃣ Context Window
#     How much text the embedding model can process at once
#
#         Long documents must be chunked
#
#         Example:
#
#             Split document → paragraph embeddings
#
#             Store each chunk separately
#
#             👉 This is why chunking strategy matters in RAG

# %% [markdown]
# #### 3️⃣ Similarity Metrics
#
#     How we compare vectors:
#
#     Metric	Meaning
#         Cosine similarity	Measures angle between vectors (most common)
#         Dot product	Faster, magnitude matters
#         Euclidean distance	Physical distance in vector space
#
# ✅ Cosine similarity is most popular in RAG systems

# %% [markdown]
# #### 4️⃣ Performance Trade-offs
#
# This is a must-know interview topic:
#
#     Factor	Trade-off
#     High dimensions	:   Better accuracy, more cost
#     Low dimensions	:   Faster, cheaper, less precise
#     Large chunk size:	More context, less precision
#     Small chunk size:	Better precision, more embeddings
#     Hosted models	 :  Easy scaling, vendor cost
#     Open-source models	Full control, infra overhead
