# %% [markdown]
# #### 🔹 What are Tools?
#
#     Tools allow LLMs to call external functions, APIs, or services instead of just generating text.

# %% [markdown]
# ### 👉 The LLM decides:
#
#     Which tool to call
#
#     With what structured arguments
#
#     When to return a final answer
#
#     This turns LLMs from chatbots → agents.

# %% [markdown]
# #### 🧠 Why Tools Matter
#
#     Without tools:
#
#         LLMs can only talk about actions
#
#     With tools:
#
#         LLMs can do actions
#
#     Examples:
#
#         Fetch real-time data
#
#         Query databases
#
#         Perform calculations
#
#         Execute code
#
#         Trigger workflows

# %% [markdown]
# #### 1️⃣ Tool Definition
#
#     A tool is defined with a name, description, and input schema.
#
# Example (conceptual):
#
#     Tool: get_order_status
#     Inputs:
#           order_id: string
#
#
# Why this matters:
#
#     Clear definitions → correct tool usage
#
#     Poor definitions → wrong calls

# %% [markdown]
# #### 2️⃣ Structured Arguments
#
#     LLMs don’t pass free text to tools. They pass structured JSON arguments.
#
# Example:
#
#     {
#       "order_id": "ORD-12345"
#     }
#
#
# Benefits:
#
#     Type safety
#
#     Validation
#
# Reliable execution
#
# 👉 This is why function calling is production-safe

# %% [markdown]
# #### 3️⃣ Tool Selection
#
#     The LLM chooses:
#
#         Whether a tool is needed
#
#         Which tool best fits the task
#
# Example:
#
#         “What’s 345 × 78?”
#
# LLM selects:
#         ➡️ Calculator tool (not reasoning in text)

# %% [markdown]
# #### 4️⃣ Model Routing
#
#     Different tasks → different models.
#
#     Example:
#
#         Task	Model
#         Reasoning	GPT-4
#         Search	Cheap fast model
#         Code execution	Sandbox model
#
# 👉 Tool calls can trigger model switching

# %% [markdown]
# #### 5️⃣ Multi-Tool Orchestration
#
#     LLMs can chain tools:
#
#         Search → Database → Calculator → Response
#
# Example:
#
#     “What was last month’s revenue growth?”
#
# Example:
#
#     “What was last month’s revenue growth?”

# %% [markdown]
# #### 🔥 Typical Agent Flow with Tools
#
#     User Query
#        ↓
#     LLM Reasoning
#        ↓
#     Tool Selection
#        ↓
#     Tool Execution
#        ↓
#     LLM Final Answer

# %% [markdown]
# #### 🚀 How This Fits with LangChain / LangGraph / MCP
#
#     LangChain → tool abstraction
#
#     LangGraph → stateful orchestration
#
#     MCP → multi-model + tool composition
#
#     Agents → autonomous tool usage
