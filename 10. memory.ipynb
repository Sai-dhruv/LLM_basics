# %% [markdown]
# #### 🔹 What is Memory?
#
#     Memory allows an LLM system to remember past interactions so conversations feel:
#
#         Continuous
#
#         Context-aware
#
#         Personalized
#
# Without memory:
#
#         Every question is treated as the first question
#
# With memory:
#
#         The system remembers what was said before

# %% [markdown]
# #### 🧠 Why Memory Matters
#
#     Memory enables:
#
#         Multi-turn conversations
#
#         Follow-up questions
#
#         Agent workflows
#
#         Personalized responses
#
#         Long-running tasks
#
# 👉 Memory = state management for LLMs

# %% [markdown]
# #### 📦 Types of Memory (Important for Interviews)

# %% [markdown]
# #### 1️⃣ BufferMemory
#     🔹 What it does
#
#             Stores entire conversation history
#
#             Appends messages verbatim
#
# 🔹 Pros / Cons
#
#         ✅ Simple
#         ❌ Context window grows fast → expensive & unsafe
#
# 🔹 When to use
#
#         Short conversations
#
#         Demos & prototypes

# %% [markdown]
# ####  2️⃣ BufferWindowMemory
# 🔹 What it does
#
#     Keeps only last N messages
#
#     Drops older messages automatically
#
# 🔹 Example
#     Keep last 5 messages
#     Discard anything before that
#
# 🔹 Benefits
#
#     Controlled token usage
#
#     Predictable cost
#
# 🔹 When to use
#
#     Chatbots
#
#     Q&A assistants

# %% [markdown]
# #### 3️⃣ ConversationSummaryMemory
# 🔹 What it does
#
#     Summarizes past conversation using an LLM
#
#     Stores compressed history
#
# 🔹 Example
#
#     Instead of:
#
#         50 messages
#
# It stores:
#
#     “User is building a RAG system using LangChain and FAISS…”
#
# 🔹 Benefits
#
#     Long conversations supported
#
# Low token usage
#
# 🔹 Trade-off
#
# ❌ Summary may lose details

# %% [markdown]
# #### 4️⃣ ConversationSummaryBufferMemory
# 🔹 What it does
#
#     Hybrid approach:
#
#         Recent messages → verbatim
#
#         Older messages → summarized
#
# 🔹 Why it’s popular
#
#         Balance between accuracy & efficiency
#
# 🔹 When to use
#
#         Production chat systems
#
#         Long-running assistants

# %% [markdown]
# #### 5️⃣ VectorStoreMemory
# 🔹 What it does
#
#         Stores conversation history as embeddings
#
#         Retrieves relevant past interactions when needed
#
# 🔹 Why it’s powerful
#
#         Long-term memory
#
#         Semantic recall
#
# Example:
#
#         “Earlier you said your project uses DynamoDB…”
#
# 🔹 When to use
#
#         Personal assistants
#
#         Agent systems
#
#         Knowledge-based memory
